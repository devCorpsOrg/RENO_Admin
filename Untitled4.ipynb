# %%
from IPython.display import clear_output
# !pip installimport warnings
warnings.filterwarnings("ignore")

import os
import sys
import cv2
import math
import umap
import keras
import shutil
import random
import imutils
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import efficientnet.tfkeras as efn


from tqdm import tqdm
from PIL import Image
from os import listdir
from scipy import misc
from keras import layers
from plotly import tools
from random import shuffle
from itertools import chain
from numpy import expand_dims
from matplotlib import pyplot 
from keras import backend as K
from keras.layers import Input
from collections import Counter
from os.path import isfile, join
from sklearn.manifold import TSNE
from skimage.transform import resize
from skimage.morphology import label
from sklearn.metrics import f1_score
from sklearn.decomposition import PCA
from IPython.display import clear_output
from sklearn.metrics import recall_score
from sklearn.datasets import make_circles
from sklearn.metrics import roc_auc_score
from keras.layers.merge import concatenate
from keras.optimizers import Adam, RMSprop
from sklearn.metrics import precision_score
from keras.layers.core import Dropout, Lambda
from sklearn.metrics import cohen_kappa_score
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.pooling import MaxPooling2D
from keras.preprocessing.image import load_img
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from keras.applications.resnet50 import ResNet50
from keras.preprocessing.image import img_to_array
from sklearn.model_selection import train_test_split
from plotly.offline import init_notebook_mode, iplot
from keras.models import Model, Sequential, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.applications.vgg19 import VGG19, preprocess_input
from sklearn.metrics import accuracy_score, confusion_matrix
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from skimage.io import imread, imshow, imread_collection, concatenate_images


init_notebook_mode(connected=True)
RANDOM_SEED = 1998
EPOCHS = 128
z imutils
# !pip install -q efficientnet
clear_output()
# Out:
#   Cell In[10], line 75
#     z imutils
#       ^
# SyntaxError: invalid syntax

# %%
# !pip install pep8
# !pip install --upgrade pep8
# Out:
# Requirement already satisfied: pep8 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (1.7.1)
# Requirement already satisfied: pep8 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (1.7.1)

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import sys
import cv2
import math
import umap
import keras
import shutil
import random
import imutils
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import efficientnet.tfkeras as efn


from tqdm import tqdm
from PIL import Image
from os import listdir
from scipy import misc
from keras import layers
from plotly import tools
from random import shuffle
from itertools import chain
from numpy import expand_dims
from matplotlib import pyplot 
from keras import backend as K
from keras.layers import Input
from collections import Counter
from os.path import isfile, join
from sklearn.manifold import TSNE
from skimage.transform import resize
from skimage.morphology import label
from sklearn.metrics import f1_score
from sklearn.decomposition import PCA
from IPython.display import clear_output
from sklearn.metrics import recall_score
from sklearn.datasets import make_circles
from sklearn.metrics import roc_auc_score
from keras.layers.merge import concatenate
from keras.optimizers import Adam, RMSprop
from sklearn.metrics import precision_score
from keras.layers.core import Dropout, Lambda
from sklearn.metrics import cohen_kappa_score
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.pooling import MaxPooling2D
from keras.preprocessing.image import load_img
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from keras.applications.resnet50 import ResNet50
from keras.preprocessing.image import img_to_array
from sklearn.model_selection import train_test_split
from plotly.offline import init_notebook_mode, iplot
from keras.models import Model, Sequential, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.applications.vgg19 import VGG19, preprocess_input
from sklearn.metrics import accuracy_score, confusion_matrix
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from skimage.io import imread, imshow, imread_collection, concatenate_images


init_notebook_mode(connected=True)
RANDOM_SEED = 1998
EPOCHS = 128
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 9
#       7 import math
#       8 import umap
# ----> 9 import keras
#      10 import shutil
#      11 import random
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/models/__init__.py:18
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/engine/functional.py:26
#      22 import warnings
#      24 import tensorflow.compat.v2 as tf
# ---> 26 from keras import backend
#      27 from keras.dtensor import layout_map as layout_map_lib
#      28 from keras.engine import base_layer
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/backend.py:32
#      29 import numpy as np
#      30 import tensorflow.compat.v2 as tf
# ---> 32 from keras import backend_config
#      33 from keras.distribute import distribute_coordinator_utils as dc
#      34 from keras.dtensor import dtensor_api as dtensor
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/backend_config.py:33
#      28 # Default image data format, one of "channels_last", "channels_first".
#      29 _IMAGE_DATA_FORMAT = "channels_last"
#      32 @keras_export("keras.backend.epsilon")
# ---> 33 @tf.__internal__.dispatch.add_dispatch_support
#      34 def epsilon():
#      35     """Returns the value of the fuzz factor used in numeric expressions.
#      36
#      37     Returns:
#    (...)
#      42     1e-07
#      43     """
#      44     return _EPSILON
#
# AttributeError: module 'tensorflow.compat.v2.__internal__' has no attribute 'dispatch'

# %%
# !pip install tensorflow==2.5.0
# Out:
# Collecting tensorflow==2.5.0
#   Downloading tensorflow-2.5.0-cp38-cp38-macosx_10_11_x86_64.whl (195.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.7/195.7 MB 2.2 MB/s eta 0:00:0000:0100:02
# Collecting numpy~=1.19.2 (from tensorflow==2.5.0)
#   Using cached numpy-1.19.5-cp38-cp38-macosx_10_9_x86_64.whl (15.6 MB)
# Requirement already satisfied: absl-py~=0.10 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorflow==2.5.0) (0.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorflow==2.5.0) (1.6.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorflow==2.5.0) (1.12)
# Requirement already satisfied: google-pasta~=0.2 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorflow==2.5.0) (0.2.0)
# Collecting h5py~=3.1.0 (from tensorflow==2.5.0)
#   Downloading h5py-3.1.0-cp38-cp38-macosx_10_9_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 4.3 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorflow==2.5.0) (1.1.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorflow==2.5.0) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorflow==2.5.0) (3.20.3)
# Requirement already satisfied: six~=1.15.0 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorflow==2.5.0) (1.15.0)
# Requirement already satisfied: termcolor~=1.1.0 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorflow==2.5.0) (1.1.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorflow==2.5.0) (3.7.4.3)
# Requirement already satisfied: wheel~=0.35 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorflow==2.5.0) (0.38.4)
# Requirement already satisfied: wrapt~=1.12.1 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorflow==2.5.0) (1.12.1)
# Collecting gast==0.4.0 (from tensorflow==2.5.0)
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: tensorboard~=2.5 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorflow==2.5.0) (2.11.2)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0 (from tensorflow==2.5.0)
#   Downloading tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.4/462.4 kB 8.1 MB/s eta 0:00:0000:01
# Collecting keras-nightly~=2.5.0.dev (from tensorflow==2.5.0)
#   Downloading keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 5.2 MB/s eta 0:00:0000:0100:01m
# Collecting grpcio~=1.34.0 (from tensorflow==2.5.0)
#   Downloading grpcio-1.34.1-cp38-cp38-macosx_10_10_x86_64.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 3.5 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (2.28.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (66.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.0) (6.0.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard~=2.5->tensorflow==2.5.0) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.0) (3.11.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (3.2.2)
# Installing collected packages: tensorflow-estimator, keras-nightly, numpy, grpcio, gast, h5py, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.32.0
#     Uninstalling grpcio-1.32.0:
#       Successfully uninstalled grpcio-1.32.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.4.0
#     Uninstalling tensorflow-2.4.0:
#       Successfully uninstalled tensorflow-2.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# matplotlib 3.7.1 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# pandas 1.5.3 requires numpy>=1.20.3, but you have numpy 1.19.5 which is incompatible.
# scikit-image 0.20.0 requires numpy>=1.21.1, but you have numpy 1.19.5 which is incompatible.
# Successfully installed gast-0.4.0 grpcio-1.34.1 h5py-3.1.0 keras-nightly-2.5.0.dev2021032900 numpy-1.19.5 tensorflow-2.5.0 tensorflow-estimator-2.5.0

# %%
# !pip install keras==2.3.1
# Out:
# Collecting keras==2.3.1
#   Downloading Keras-2.3.1-py2.py3-none-any.whl (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.8/377.8 kB 5.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.9.1 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from keras==2.3.1) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from keras==2.3.1) (1.9.1)
# Requirement already satisfied: six>=1.9.0 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from keras==2.3.1) (1.15.0)
# Requirement already satisfied: pyyaml in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from keras==2.3.1) (6.0)
# Requirement already satisfied: h5py in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from keras==2.3.1) (3.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from keras==2.3.1) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (from keras==2.3.1) (1.1.2)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
# Successfully installed keras-2.3.1

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import sys
import cv2
import math
import umap
import keras
import shutil
import random
import imutils
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import efficientnet.tfkeras as efn


from tqdm import tqdm
from PIL import Image
from os import listdir
from scipy import misc
from keras import layers
from plotly import tools
from random import shuffle
from itertools import chain
from numpy import expand_dims
from matplotlib import pyplot 
from keras import backend as K
from keras.layers import Input
from collections import Counter
from os.path import isfile, join
from sklearn.manifold import TSNE
from skimage.transform import resize
from skimage.morphology import label
from sklearn.metrics import f1_score
from sklearn.decomposition import PCA
from IPython.display import clear_output
from sklearn.metrics import recall_score
from sklearn.datasets import make_circles
from sklearn.metrics import roc_auc_score
from keras.layers.merge import concatenate
from keras.optimizers import Adam, RMSprop
from sklearn.metrics import precision_score
from keras.layers.core import Dropout, Lambda
from sklearn.metrics import cohen_kappa_score
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.pooling import MaxPooling2D
from keras.preprocessing.image import load_img
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from keras.applications.resnet50 import ResNet50
from keras.preprocessing.image import img_to_array
from sklearn.model_selection import train_test_split
from plotly.offline import init_notebook_mode, iplot
from keras.models import Model, Sequential, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.applications.vgg19 import VGG19, preprocess_input
from sklearn.metrics import accuracy_score, confusion_matrix
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from skimage.io import imread, imshow, imread_collection, concatenate_images


init_notebook_mode(connected=True)
RANDOM_SEED = 1998
EPOCHS = 128
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 9
#       7 import math
#       8 import umap
# ----> 9 import keras
#      10 import shutil
#      11 import random
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/__init__.py:3
#       1 # Copyright 2015 The TensorFlow Authors. All Rights Reserved.
#       2 #
# ----> 3 # Licensed under the Apache License, Version 2.0 (the "License");
#       4 # you may not use this file except in compliance with the License.
#       5 # You may obtain a copy of the License at
#       6 #
#       7 #     http://www.apache.org/licenses/LICENSE-2.0
#       8 #
#       9 # Unless required by applicable law or agreed to in writing, software
#      10 # distributed under the License is distributed on an "AS IS" BASIS,
#      11 # WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/utils/__init__.py:26
#      24 from .layer_utils import get_source_inputs
#      25 from .layer_utils import print_summary
# ---> 26 from .vis_utils import model_to_dot
#      27 from .vis_utils import plot_model
#      28 from .np_utils import to_categorical
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/utils/vis_utils.py:7
#       4 from __future__ import print_function
#       6 import os
# ----> 7 from ..models import Model
#       8 from ..layers.wrappers import Wrapper
#      10 # `pydot` is an optional dependency,
#      11 # see `extras_require` in `setup.py`.
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/models.py:12
#      10 from .engine.input_layer import Input
#      11 from .engine.input_layer import InputLayer
# ---> 12 from .engine.training import Model
#      13 from .engine.sequential import Sequential
#      14 from .engine.saving import save_model
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/engine/training.py:14
#      12 from .network import Network
#      13 from .base_layer import Layer
# ---> 14 from . import training_utils
#      15 from . import training_arrays
#      16 from . import training_generator
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/engine/training_utils.py:17
#      15 from .. import backend as K
#      16 from .. import losses
# ---> 17 from .. import metrics as metrics_module
#      18 from ..utils import Sequence
#      19 from ..utils import generic_utils
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/metrics.py:13
#      10 import types
#      12 from . import backend as K
# ---> 13 from .layers import Layer
#      14 from .losses import mean_squared_error
#      15 from .losses import mean_absolute_error
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/layers/__init__.py:5
#       3 from ..utils.generic_utils import deserialize_keras_object
#       4 from ..engine.base_layer import Layer
# ----> 5 from ..engine import Input
#       6 from ..engine import InputLayer
#       7 from ..engine.base_layer import InputSpec
#
# ImportError: cannot import name 'Input' from 'keras.engine' (/Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/engine/__init__.py)

# %%
# !pip install --upgrade keras
# Out:
# Requirement already satisfied: keras in /Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages (2.3.1)
# Collecting keras
#   Using cached keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# Successfully installed keras-2.12.0

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import sys
import cv2
import math
import umap
import keras
import shutil
import random
import imutils
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import efficientnet.tfkeras as efn


from tqdm import tqdm
from PIL import Image
from os import listdir
from scipy import misc
from keras import layers
from plotly import tools
from random import shuffle
from itertools import chain
from numpy import expand_dims
from matplotlib import pyplot 
from keras import backend as K
from keras.layers import Input
from collections import Counter
from os.path import isfile, join
from sklearn.manifold import TSNE
from skimage.transform import resize
from skimage.morphology import label
from sklearn.metrics import f1_score
from sklearn.decomposition import PCA
from IPython.display import clear_output
from sklearn.metrics import recall_score
from sklearn.datasets import make_circles
from sklearn.metrics import roc_auc_score
from keras.layers.merge import concatenate
from keras.optimizers import Adam, RMSprop
from sklearn.metrics import precision_score
from keras.layers.core import Dropout, Lambda
from sklearn.metrics import cohen_kappa_score
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.pooling import MaxPooling2D
from keras.preprocessing.image import load_img
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from keras.applications.resnet50 import ResNet50
from keras.preprocessing.image import img_to_array
from sklearn.model_selection import train_test_split
from plotly.offline import init_notebook_mode, iplot
from keras.models import Model, Sequential, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.applications.vgg19 import VGG19, preprocess_input
from sklearn.metrics import accuracy_score, confusion_matrix
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.layers.convolutional import Conv2D, Conv2DTranspose
import warnings
warnings.filterwarnings("ignore")

import os
import sys
import cv2
import math
import umap
import keras
import shutil
import random
import imutils
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import efficientnet.tfkeras as efn


from tqdm import tqdm
from PIL import Image
from os import listdir
from scipy import misc
from keras import layers
from plotly import tools
from random import shuffle
from itertools import chain
from numpy import expand_dims
from matplotlib import pyplot 
from keras import backend as K
from keras.layers import Input
from collections import Counter
from os.path import isfile, join
from sklearn.manifold import TSNE
from skimage.transform import resize
from skimage.morphology import label
from sklearn.metrics import f1_score
from sklearn.decomposition import PCA
from IPython.display import clear_output
from sklearn.metrics import recall_score
from sklearn.datasets import make_circles
from sklearn.metrics import roc_auc_score
from keras.layers.merge import concatenate
from keras.optimizers import Adam, RMSprop
from sklearn.metrics import precision_score
from keras.layers.core import Dropout, Lambda
from sklearn.metrics import cohen_kappa_score
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.pooling import MaxPooling2D
from keras.preprocessing.image import load_img
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from keras.applications.resnet50 import ResNet50
from keras.preprocessing.image import img_to_array
from sklearn.model_selection import train_test_split
from plotly.offline import init_notebook_mode, iplot
from keras.models import Model, Sequential, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.applications.vgg19 import VGG19, preprocess_input
from sklearn.metrics import accuracy_score, confusion_matrix
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from skimage.io import imread, imshow, imread_collection, concatenate_images


init_notebook_mode(connected=True)
RANDOM_SEED = 1998
EPOCHS = 128
from skimage.io import imread, imshow, imread_collection, concatenate_images


init_notebook_mode(connected=True)
RANDOM_SEED = 1998
EPOCHS = 128
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 9
#       7 import math
#       8 import umap
# ----> 9 import keras
#      10 import shutil
#      11 import random
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/models/__init__.py:18
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/engine/functional.py:27
#      24 import tensorflow.compat.v2 as tf
#      26 from keras import backend
# ---> 27 from keras.dtensor import layout_map as layout_map_lib
#      28 from keras.engine import base_layer
#      29 from keras.engine import base_layer_utils
#
# File ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/keras/dtensor/__init__.py:22
#      20 # Conditional import the dtensor API, since it is currently broken in OSS.
#      21 if _DTENSOR_API_ENABLED:
# ---> 22     from tensorflow.compat.v2.experimental import dtensor as dtensor_api
#      23 else:
#      24     # Leave it with a placeholder, so that the import line from other python
#      25     # file will not break.
#      26     dtensor_api = None
#
# ImportError: cannot import name 'dtensor' from 'tensorflow.compat.v2.experimental' (/Users/prashantdhiman142/miniconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/_api/v2/compat/v2/experimental/__init__.py)
